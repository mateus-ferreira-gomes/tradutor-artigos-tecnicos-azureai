# %% [markdown]
# <a href="https://colab.research.google.com/github/mateus-ferreira-gomes/tradutor-artigos-tecnicos-azureai/blob/main/notebooks/tradutor_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 Tradutor de Documentos Word com Azure Translator
#
# Este notebook traduz arquivos `.docx` para português usando a API do Azure Translator.
# Ele está organizado em células que instalam dependências, configuram a API, testam a tradução e aplicam a função em um documento Word.

# %%
# 📌 Instalar dependências

# !pip install requests python-docx
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Collecting python-docx
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.2.25)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (6.0.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (4.15.0)
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 4.8 MB/s eta 0:00:00
# Installing collected packages: python-docx
# Successfully installed python-docx-1.2.0

# %%
# 📌 Importações

import requests
from docx import Document
import os

# %%
# 📌 Configurações da API

# IMPORTANTE:
# Para executar o projeto, substitua os valores abaixo pelas suas credenciais do Azure Translator.
subscription_key = "YOUR_AZURE_TRANSLATOR_KEY"
endpoint = "YOUR_AZURE_TRANSLATOR_ENDPOINT"
location = "YOUR_AZURE_REGION"
language_destination = "pt-br"

def translator_text(text, target_language):
    path = '/translate'
    constructed_url = endpoint + path
    headers = {
        'Ocp-Apim-Subscription-Key': subscription_key,
        'Ocp-Apim-Subscription-Region': location,
        'Content-type': 'application/json',
        'X-ClientTraceId': str(os.urandom(16))
    }

    body = [{
        'text': text
    }]
    params = {
        'api-version': '3.0',
        'to': target_language
    }

    request = requests.post(constructed_url, params=params, headers=headers, json=body)
    response = request.json()
    return response[0]['translations'][0]['text']

# %%
# 📌 Teste rápido da função de tradução

translator_text("I know you're somewhere out there, somewhere far away", language_destination)
# Out:
# 'Eu sei que você está em algum lugar lá fora, em algum lugar bem longe'

# %%
# 📌Importa a função centralizada de tradução
# A função `translate_document` agora está centralizada em utils.py
# Isso permite que o mesmo código seja reutilizado em diferentes notebooks ou scripts,
# mantendo consistência e evitando duplicação de lógica.
from src.utils import translate_document

# Caminho do arquivo Word que será traduzido
# Substitua pelo caminho do seu documento (.docx) que deseja traduzir
input_file = "/content/musica.docx"

# Executa a tradução do documento
# A função percorre todos os parágrafos, traduz cada um usando Azure Translator
# e gera um novo arquivo com sufixo de idioma, preservando a estrutura do original.
translate_document(input_file)

# %%
# 📌 Rodando tradução no arquivo

# Define o caminho do arquivo de entrada
input_file = "/content/musica.docx"

# Chama a função para traduzir o documento especificado
translate_document(input_file)
# Out:
# Falando com a Lua
# Música por
# Bruno Mars
#
# Eu sei que você está em algum lugar lá fora, em algum lugar bem longe
# Eu quero você de volta, eu quero você de volta
# Meus vizinhos acham que sou louco, mas não entendem
# Você era tudo o que eu tinha, você era tudo o que eu tinha
#
# À noite, quando as estrelas iluminam meu quarto
# Eu sento sozinho
#
# Falando com a lua
# Tentando chegar até você
# Na esperança de que você também esteja do outro lado conversando comigo
# Ou sou um tolo que fica sozinho conversando com a lua?
# Ah
#
# Estou me sentindo famoso, o assunto da cidade
# Dizem que eu enlouqueci, sim, eu enlouqueci
# Mas eles não sabem o que eu sei, porque quando o sol se põe
# Alguém está respondendo, sim, está respondendo, ah
#
# À noite, quando as estrelas iluminam meu quarto
# Eu sento sozinho
#
# Falando com a lua
# Tentando chegar até você
# Na esperança de que você também esteja do outro lado conversando comigo
# Ou sou um tolo que fica sozinho conversando com a lua?
#
# Ahhh
# Você já me ouve chamando?
# (Ah) oh-oh-oh (ah), oh-oh-oh (ah)
#
# Porque toda noite eu falo com a lua
# Ainda tentando chegar até você
# Na esperança de que você também esteja do outro lado conversando comigo
# Ou sou um tolo que fica sozinho conversando com a lua?
# Ah
#
# Eu sei que você está em algum lugar lá fora, em algum lugar bem longe
#
# Compositores: Bruno Mars, Philip Lawrence, Ari Levine, Albert Winkler, Jeffrey Bhasker. Somente para uso não comercial.
# '/content/musica_pt-br.docx'
